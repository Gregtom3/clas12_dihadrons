# %%
# %run ../../utils/helper.ipynb
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-r8yy0y5r because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# Welcome to JupyROOT 6.22/06

# %%
project_dir = "/work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_vrgc/"
channel = "piplus_piminus"
version = "Data_RGC"
tree = "dihadron"

# %%
canvas=plot_graph(    project_dir, channel, version, tree,
                      x_col="x", x_min=0, x_max=1, x_bins = 100,
                      y_col="Q2", y_min=0, y_max=10,  y_bins = 100,
                      set_log_z = True,
                      latex_xmax = 0.5, latex_ymax=0.2,
                      #z_min=0.3,z_max=1.1,z_col="p/truep",
                      cut="A==12"
                      )
canvas.Draw()
# Out:
# Name: dihadron Title: Dihadron-by-Dihadron info

# %%
canvas=plot_graph(    project_dir, channel, version, tree,
                      x_col="xF1", x_min=-1, x_max=1, x_bins = 100,
                      latex_xmax = 0.5, latex_ymax=0.2
                      #z_min=0.3,z_max=1.1,z_col="p/truep",
                      #cut=""
                      )
canvas.Draw()
# Out:
# Name: dihadron Title: Dihadron-by-Dihadron info

# %%
[b.GetName() for b in canvas.GetListOfPrimitives()]
# Out:
# ['TFrame', 'hist', '']

# %%
canvas.GetListOfPrimitives()[1].GetEntries()
# Out:
# 1381953.0
