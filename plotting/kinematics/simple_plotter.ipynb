# %%
# %run ../../utils/helper.ipynb
# Out:
# Welcome to JupyROOT 6.22/06
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-cesx00p0 because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
project_dir = "/work/clas12/users/gmat/clas12/clas12_dihadrons/projects/pipi0_paper_RGA_only/"
channel = "piplus_piminus"
version = "MC_RGA_inbending"
tree = "dihadron" # EventTree or dihadron

# %% [markdown]
# `plot_graph(**args)`
# - `project_dir`: The path to the project directory.
# - `channel`: The channel being analyzed (e.g. piplus_piminus, piminus_piminus, pi0_pi0).
# - `version`: The version of the data being analyzed (e.g. MC_RGA_inbending, Data_RGC).
# - `ttree`: The name of the ROOT TTree containing the data to be plotted.
# - `x_col`: The name of the column to be plotted on the x-axis.
# - `x_min`: The minimum value for the x-axis range.
# - `x_max`: The maximum value for the x-axis range.
# - `x_bins`: The number of bins to use for the x-axis histogram. If not specified, defaults to 50.
# - `y_col`: The name of the column to be plotted on the y-axis. If not specified, a 1-dimensional histogram is created.
# - `y_min`: The minimum value for the y-axis range.
# - `y_max`: The maximum value for the y-axis range.
# - `y_bins`: The number of bins to use for the y-axis histogram. If not specified, defaults to 50.
# - `set_log_y`: Set to `True` to use a logarithmic scale for the y-axis.
# - `z_min`: The minimum value for the z-axis range (for 2D histograms).
# - `z_max`: The maximum value for the z-axis range (for 2D histograms).
# - `z_col`: The name of the column to be used for the z scaling
# - `set_log_z`: Set to `True` to use a logarithmic scale for the z-axis (for 2D histograms).
# - `cut`: The selection criteria to apply to the data.
# - `nbins`: The default number of bins to use for histograms.
# - `latex_xmax`: The x-coordinate for the top-right corner of the title text.
# - `latex_ymax`: The y-coordinate for the top-right corner of the title text.
# - `alias_x`: An alias for the x-axis column name.
# - `alias_y`: An alias for the y-axis column name.
# - `alias_z`: An alias for the z-axis column name.
# - `suffix`: A suffix to add to the filename for saving the plot. If not specified, the plot is not saved to a file.

# %%
canvas=plot_graph(    project_dir, channel, version, tree,
                      x_col="P1", x_min=0, x_max=5, x_bins = 100,
                      y_col="trueP1", y_min=0, y_max=5,  y_bins = 100,
                      set_log_z = True,
                      latex_xmax = 0.5, latex_ymax=0.2,
                      #z_min=0.3,z_max=1.1,z_col="p/truep",
                      )
canvas.Draw()
# Out:
# Name: dihadron Title: Dihadron-by-Dihadron info

# %%
canvas=plot_graph(    project_dir, channel, version, tree,
                      x_col="Mh", x_min=0.3, x_max=2, x_bins = 100, x_title = "M_{h}(#pi^{+}#pi^{-})",
                      latex_xmax = 0.47, latex_ymax=0.8, y_title = "Counts"
                      #z_min=0.3,z_max=1.1,z_col="p/truep",
                      )
canvas.Draw()
# Out:
# Name: dihadron Title: Dihadron-by-Dihadron info

# %%
channel = "pi0_pi0"
canvas=plot_graph(    project_dir, channel, version, tree,
                      x_col="Mx", x_min=0, x_max=4, x_bins = 100, x_title = "Missing Mass [GeV]",
                      latex_xmax = 0.47, latex_ymax=0.8, y_title = "Counts",
                      cut="p_11>0.9&&p_12>0.9&&p_21>0.9&&p_22>0.9"
                      #z_min=0.3,z_max=1.1,z_col="p/truep",
                      )
canvas.Draw()
# Out:
# Name: dihadron Title: Dihadron-by-Dihadron info

# %%
import ROOT
f=ROOT.TFile("../../projects/ana_v1/volatile/data/pi0_pi0/Fall2018_RGA_inbending_merged.root")
t=f.Get("dihadron")
c=ROOT.TCanvas()
# Out:
# Welcome to JupyROOT 6.22/06

# %%
t.Draw("Mx","p_11>0.9&&p_12>0.9&&p_21>0.9&&p_22>0.9","",10000)
c.Draw()

# %%
channel = "pi0_pi0"
canvas=plot_graph(    project_dir, channel, version, tree,
                      x_col="Mx", x_min=0, x_max=4, x_bins = 100, x_title = "Missing Mass [GeV]",
                      latex_xmax = 0.47, latex_ymax=0.8, y_title = "Counts",
                      cut="p_11>0.9&&p_12>0.9&&p_21>0.9&&p_22>0.9"
                      #z_min=0.3,z_max=1.1,z_col="p/truep",
                      )
canvas.Draw()

# %% [markdown]
# # Rho Production
# ---

# %%
# Piplus Piminus Production
project_dir = "/work/clas12/users/gmat/clas12/clas12_dihadrons/projects/pipi0_paper_RGA_only/"
channel = "piplus_piminus"
version = "MC_RGA_inbending"
tree = "dihadron_cuts" # EventTree or dihadron

# %%
canvas=plot_graph(    project_dir, channel, version, tree,
                      x_col="Mh", x_min=0.2, x_max=3.3, x_bins = 100, x_title = "Dihadron Mass [GeV]", y_title="Counts",
                      cut="Mx<1.1",
                      latex_xmax = 0.45, latex_ymax=0.85
                      #z_min=0.3,z_max=1.1,z_col="p/truep",
                      )
canvas.Draw()
# Out:
# Name: dihadron_cuts Title: Dihadron-by-Dihadron info

# %%
canvas=plot_graph(    project_dir, channel, version, tree,
                      x_col="Mx", x_min=0.2, x_max=3.3, x_bins = 100, x_title = "Missing Mass", y_title="Fraction #rho^{0}",
                      z_col="trueparentpid_1==113&&trueparentpid_2==113&&trueparentid_1==trueparentid_2",
                      latex_xmax = 0.45, latex_ymax=0.85, cut="", y_min=0, y_max=0.33
                      #z_min=0.3,z_max=1.1,z_col="p/truep",
                      )
canvas.Draw()
# Out:
# Name: dihadron_cuts Title: Dihadron-by-Dihadron info
# 4526625.0

# %%
canvas=plot_graph(    project_dir, channel, version, tree,
                      x_col="Mx", x_min=0.2, x_max=3.3, x_bins = 100, x_title = "Missing Mass", y_title="Fraction #rho^{0}",
                      z_col="trueparentpid_1==113&&trueparentpid_2==113&&trueparentid_1==trueparentid_2",
                      latex_xmax = 0.45, latex_ymax=0.85, cut="xF<0&&P1>1.25&&P2>1.25", y_min=0, y_max=0.33
                      #z_min=0.3,z_max=1.1,z_col="p/truep",
                      )
canvas.Draw()
# Out:
# Name: dihadron Title: Dihadron-by-Dihadron info
# 233455.0

# %%
canvas=plot_graph(    project_dir, channel, version, tree,
                      x_col="Mx", x_min=0.2, x_max=3.3, x_bins = 100, x_title = "Missing Mass", y_title="Fraction #rho^{0}",
                      z_col="trueparentpid_1==113&&trueparentpid_2==113&&trueparentid_1==trueparentid_2",
                      latex_xmax = 0.45, latex_ymax=0.85, cut="xF>0&&P1>1.25&&P2>1.25", y_min=0, y_max=0.33
                      #z_min=0.3,z_max=1.1,z_col="p/truep",
                      )
canvas.Draw()
# Out:
# Name: dihadron Title: Dihadron-by-Dihadron info
# 7657982.0

# %%
canvas=plot_graph(    project_dir, channel, version, tree,
                      x_col="xF", x_min=-0.5, x_max=1, x_bins = 100, x_title = "x-Feynman (#pi^{+}#pi^{-})", y_title="Fraction #rho^{0}",
                      z_col="trueparentpid_1==113&&trueparentpid_2==113&&trueparentid_1==trueparentid_2",
                      latex_xmax = 0.2, latex_ymax=0.8
                      #z_min=0.3,z_max=1.1,z_col="p/truep",
                      )
canvas.Draw()
# Out:
# Name: dihadron Title: Dihadron-by-Dihadron info
# 5063987.0

# %%
canvas=plot_graph(    project_dir, channel, version, tree,
                      x_col="Mh", x_min=0.4, x_max=1.1, x_bins = 100, x_title = "M(#pi^{+}#pi^{-})", y_title="Fraction #rho^{0}",
                      z_col="trueparentpid_1==113&&trueparentpid_2==113&&trueparentid_1==trueparentid_2",
                      latex_xmax = 0.2, latex_ymax=0.8
                      #z_min=0.3,z_max=1.1,z_col="p/truep",
                      )
canvas.Draw()
# Out:
# Name: dihadron Title: Dihadron-by-Dihadron info
# 5063987.0

# %%
canvas=plot_graph(    project_dir, channel, version, tree,
                      x_col="phi_R0", x_min=-3.14, x_max=3.14, x_bins = 100, x_title = "#phi_{R}", y_title="Fraction #rho^{0}",
                      z_col="trueparentpid_1==113&&trueparentpid_2==113&&trueparentid_1==trueparentid_2",
                      latex_xmax = 0.2, latex_ymax=0.8
                      #z_min=0.3,z_max=1.1,z_col="p/truep",
                      )
canvas.Draw()
# Out:
# Name: dihadron Title: Dihadron-by-Dihadron info
# 5063987.0

# %%
canvas=plot_graph(    project_dir, channel, version, tree,
                      x_col="xF", x_min=-0.3, x_max=1, x_bins = 100, x_title = "x-Feynman (#pi^{+}#pi^{-})", 
                      y_col="z",  y_min=0, y_max=1.1, y_bins=100, y_title = "z (#pi^{+}#pi^{-})",
                      z_col="trueparentpid_1==113&&trueparentpid_2==113&&trueparentid_1==trueparentid_2",z_title="Fraction #rho^{0}",
                      latex_xmax = 0.2, latex_ymax=0.8
                      #z_min=0.3,z_max=1.1,z_col="p/truep",
                      )
canvas.Draw()
# Out:
# Name: dihadron Title: Dihadron-by-Dihadron info

# %%
canvas=plot_graph(    project_dir, channel, version, tree,
                      x_col="pTtot", x_min=-0, x_max=1.5, x_bins = 100, x_title = "p_{T}[GeV] (#pi^{+}#pi^{-})", 
                      y_col="z",  y_min=0, y_max=1.1, y_bins=100, y_title = "z (#pi^{+}#pi^{-})",
                      z_col="trueparentpid_1==113&&trueparentpid_2==113&&trueparentid_1==trueparentid_2",z_title="Fraction #rho^{0}",
                      latex_xmax = 0.2, latex_ymax=0.8
                      #z_min=0.3,z_max=1.1,z_col="p/truep",
                      )
canvas.Draw()
# Out:
# Name: dihadron_cuts Title: Dihadron-by-Dihadron info

# %% [markdown]
# # Rho+

# %%
# Piplus Piminus Production
project_dir = "/work/clas12/users/gmat/clas12/clas12_dihadrons/projects/pipi0_paper_RGA_only/"
channel = "piplus_pi0"
version = "MC_RGA_inbending"
tree = "dihadron_cuts" # EventTree or dihadron

# %%
canvas=plot_graph(    project_dir, channel, version, tree,
                      x_col="z", x_min=0.2, x_max=1, x_bins = 100, x_title = "z", y_title="Fraction #rho^{+}",
                      z_col="trueparentpid_1==213&&trueparentparentpid_2==213&&trueparentid_1==trueparentparentid_2",
                      latex_xmax = 0.45, latex_ymax=0.85, cut="", y_min=0, y_max=0.33
                      #z_min=0.3,z_max=1.1,z_col="p/truep",
                      )
canvas.Draw()
# Out:
# Name: dihadron_cuts Title: Dihadron-by-Dihadron info
# 11171113.0

# %%
canvas=plot_graph(    project_dir, channel, version, tree,
                      x_col="x", x_min=0.2, x_max=1, x_bins = 100, x_title = "x", y_title="Fraction #rho^{+}",
                      z_col="trueparentpid_1==213&&trueparentparentpid_2==213&&trueparentid_1==trueparentparentid_2",
                      latex_xmax = 0.45, latex_ymax=0.85, cut="", y_min=0, y_max=0.33
                      #z_min=0.3,z_max=1.1,z_col="p/truep",
                      )
canvas.Draw()
# Out:
# Name: dihadron_cuts Title: Dihadron-by-Dihadron info
# 11171113.0

# %%
canvas=plot_graph(    project_dir, channel, version, tree,
                      x_col="xF", x_min=0, x_max=1, x_bins = 100, x_title = "x-Feynman", y_title="Fraction #rho^{+}",
                      z_col="trueparentpid_1==213&&trueparentparentpid_2==213&&trueparentid_1==trueparentparentid_2",
                      latex_xmax = 0.45, latex_ymax=0.85, cut="", y_min=0, y_max=0.33
                      #z_min=0.3,z_max=1.1,z_col="p/truep",
                      )
canvas.Draw()
# Out:
# Name: dihadron_cuts Title: Dihadron-by-Dihadron info
# 11171113.0

# %%
canvas=plot_graph(    project_dir, channel, version, tree,
                      x_col="pTtot", x_min=0, x_max=1.5, x_bins = 100, x_title = "p_{T} [GeV]", y_title="Fraction #rho^{+}",
                      z_col="trueparentpid_1==213&&trueparentparentpid_2==213&&trueparentid_1==trueparentparentid_2",
                      latex_xmax = 0.45, latex_ymax=0.85, cut="", y_min=0, y_max=0.33
                      #z_min=0.3,z_max=1.1,z_col="p/truep",
                      )
canvas.Draw()
# Out:
# Name: dihadron_cuts Title: Dihadron-by-Dihadron info
# 11171113.0

# %%
canvas=plot_graph(    project_dir, channel, version, tree,
                      x_col="xF", x_min=-0.3, x_max=1, x_bins = 100, x_title = "x-Feynman (#pi^{+}#pi^{0})", 
                      y_col="z",  y_min=0, y_max=1.1, y_bins=100, y_title = "z (#pi^{+}#pi^{0})",
                      z_col="trueparentpid_1==213&&trueparentparentpid_2==213&&trueparentid_1==trueparentparentid_2",z_title="Fraction #rho^{+}",
                      latex_xmax = 0.2, latex_ymax=0.8
                      #z_min=0.3,z_max=1.1,z_col="p/truep",
                      )
canvas.Draw()
# Out:
# Name: dihadron_cuts Title: Dihadron-by-Dihadron info

# %%
canvas=plot_graph(    project_dir, channel, version, tree,
                      x_col="pTtot", x_min=-0, x_max=1.5, x_bins = 100, x_title = "p_{T}[GeV] (#pi^{+}#pi^{0})", 
                      y_col="z",  y_min=0, y_max=1.1, y_bins=100, y_title = "z (#pi^{+}#pi^{0})",
                      z_col="trueparentpid_1==213&&trueparentparentpid_2==213&&trueparentid_1==trueparentparentid_2",z_title="Fraction #rho^{+}",
                      latex_xmax = 0.2, latex_ymax=0.8
                      #z_min=0.3,z_max=1.1,z_col="p/truep",
                      )
canvas.Draw()
# Out:
# Name: dihadron_cuts Title: Dihadron-by-Dihadron info

# %% [markdown]
# # Rho -

# %%
# Piplus Piminus Production
project_dir = "/work/clas12/users/gmat/clas12/clas12_dihadrons/projects/pipi0_paper_RGA_only/"
channel = "piminus_pi0"
version = "MC_RGA_outbending"
tree = "dihadron_cuts" # EventTree or dihadron

# %%
canvas=plot_graph(    project_dir, channel, version, tree,
                      x_col="pTtot", x_min=-0, x_max=1.5, x_bins = 100, x_title = "p_{T}[GeV] (#pi^{-}#pi^{0})", 
                      y_col="z",  y_min=0, y_max=1.1, y_bins=100, y_title = "z (#pi^{-}#pi^{0})",
                      z_col="trueparentpid_1==-213&&trueparentparentpid_2==-213&&trueparentid_1==trueparentparentid_2",z_title="Fraction #rho^{-}",
                      latex_xmax = 0.2, latex_ymax=0.8
                      #z_min=0.3,z_max=1.1,z_col="p/truep",
                      )
canvas.Draw()
# Out:
# Name: dihadron_cuts Title: Dihadron-by-Dihadron info
