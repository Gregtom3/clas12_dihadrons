# %%
# %run ../../utils/helper.ipynb
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-fyi0wrlv because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# Welcome to JupyROOT 6.22/06

# %%
path_to_repo="/work/clas12/users/gmat/clas12/clas12_dihadrons"
project_name = "ana_v1"
project_dir=f"{path_to_repo}/projects/{project_name}"

# Read the YAML file for the Binning
with open(f"{path_to_repo}/utils/binning_files/Binning.yaml", "r") as file:
    data = yaml.safe_load(file)

# %%
binstructs = data["binningStructures"]
versions = ["MC_RGA_inbending","MC_RGA_outbending"]
channels = ["piplus_piminus", "piplus_pi0", "piplus_piplus","pi0_pi0","piminus_pi0", "piminus_piminus"]
cuts = ["v3","v4","v6","v1","v4","v6"]

# For loop over all binstructs
for binstruct in binstructs:
    # For loop over all Monte Carlos
    for version in versions:
        # For loop over all channels
        for channel,cut in zip(channels,cuts):
            bin_migration(project_dir,channel,version,binstruct,cut)
# Out:
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piminus/matrix_x_MC_RGA_inbending_v3.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_pi0/matrix_x_MC_RGA_inbending_v4.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piplus/matrix_x_MC_RGA_inbending_v6.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/pi0_pi0/matrix_x_MC_RGA_inbending_v1.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_pi0/matrix_x_MC_RGA_inbending_v4.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_piminus/matrix_x_MC_RGA_inbending_v6.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piminus/matrix_x_MC_RGA_outbending_v3.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_pi0/matrix_x_MC_RGA_outbending_v4.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piplus/matrix_x_MC_RGA_outbending_v6.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/pi0_pi0/matrix_x_MC_RGA_outbending_v1.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_pi0/matrix_x_MC_RGA_outbending_v4.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_piminus/matrix_x_MC_RGA_outbending_v6.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piminus/matrix_z_MC_RGA_inbending_v3.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_pi0/matrix_z_MC_RGA_inbending_v4.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piplus/matrix_z_MC_RGA_inbending_v6.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/pi0_pi0/matrix_z_MC_RGA_inbending_v1.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_pi0/matrix_z_MC_RGA_inbending_v4.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_piminus/matrix_z_MC_RGA_inbending_v6.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piminus/matrix_z_MC_RGA_outbending_v3.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_pi0/matrix_z_MC_RGA_outbending_v4.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piplus/matrix_z_MC_RGA_outbending_v6.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/pi0_pi0/matrix_z_MC_RGA_outbending_v1.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_pi0/matrix_z_MC_RGA_outbending_v4.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_piminus/matrix_z_MC_RGA_outbending_v6.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piminus/matrix_Mh_MC_RGA_inbending_v3.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_pi0/matrix_Mh_MC_RGA_inbending_v4.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piplus/matrix_Mh_MC_RGA_inbending_v6.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/pi0_pi0/matrix_Mh_MC_RGA_inbending_v1.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_pi0/matrix_Mh_MC_RGA_inbending_v4.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_piminus/matrix_Mh_MC_RGA_inbending_v6.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piminus/matrix_Mh_MC_RGA_outbending_v3.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_pi0/matrix_Mh_MC_RGA_outbending_v4.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piplus/matrix_Mh_MC_RGA_outbending_v6.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/pi0_pi0/matrix_Mh_MC_RGA_outbending_v1.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_pi0/matrix_Mh_MC_RGA_outbending_v4.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_piminus/matrix_Mh_MC_RGA_outbending_v6.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piminus/matrix_x_Mh_MC_RGA_inbending_v3.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_pi0/matrix_x_Mh_MC_RGA_inbending_v4.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piplus/matrix_x_Mh_MC_RGA_inbending_v6.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/pi0_pi0/matrix_x_Mh_MC_RGA_inbending_v1.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_pi0/matrix_x_Mh_MC_RGA_inbending_v4.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_piminus/matrix_x_Mh_MC_RGA_inbending_v6.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piminus/matrix_x_Mh_MC_RGA_outbending_v3.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_pi0/matrix_x_Mh_MC_RGA_outbending_v4.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piplus/matrix_x_Mh_MC_RGA_outbending_v6.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/pi0_pi0/matrix_x_Mh_MC_RGA_outbending_v1.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_pi0/matrix_x_Mh_MC_RGA_outbending_v4.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_piminus/matrix_x_Mh_MC_RGA_outbending_v6.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piminus/matrix_z_Mh_MC_RGA_inbending_v3.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_pi0/matrix_z_Mh_MC_RGA_inbending_v4.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piplus/matrix_z_Mh_MC_RGA_inbending_v6.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/pi0_pi0/matrix_z_Mh_MC_RGA_inbending_v1.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_pi0/matrix_z_Mh_MC_RGA_inbending_v4.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_piminus/matrix_z_Mh_MC_RGA_inbending_v6.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piminus/matrix_z_Mh_MC_RGA_outbending_v3.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_pi0/matrix_z_Mh_MC_RGA_outbending_v4.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piplus/matrix_z_Mh_MC_RGA_outbending_v6.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/pi0_pi0/matrix_z_Mh_MC_RGA_outbending_v1.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_pi0/matrix_z_Mh_MC_RGA_outbending_v4.csv
# Saved to /work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_piminus/matrix_z_Mh_MC_RGA_outbending_v6.csv

# %%
import os

# Define the output filename for the LaTeX file
latex_filename = f"{project_dir}/systematics/bin_migration/plots.tex"

# Open the LaTeX file for writing
with open(latex_filename, "w") as f:
    # Write the LaTeX document preamble
    f.write("\\documentclass{article}\n")
    f.write("\\usepackage{graphicx}\n")
    #f.write("\\usepackage{caption}\n")
    f.write("\\usepackage{geometry}\n")
    f.write("\\usepackage{fancyhdr}\n")

    f.write("\\geometry{margin=2cm}\n") # Set the margin to 1 cm
    f.write("\\usepackage[font=large]{caption}\n") # Set the caption font size to large
    f.write("\\begin{document}\n")
    f.write("\\pagestyle{fancy}\n")
    f.write("\\fancyhf{}\n")
    f.write("\\fancyhead[L]{\\leftmark\\,\\,\\,\\,\\rightmark}\n")
    f.write("\\fancyhead[R]{\\thepage}\n")
    # Add a table of contents
    f.write("\\tableofcontents\n")
    # Loop over all channels
    for channel,cut in zip(channels,cuts):
        CHANNEL=channel.replace("piplus","$\\pi^{+}$").replace("piminus","$\\pi^{-}$").replace("pi0","$\\pi^{0}$").replace("_","")
        f.write(f"\\section{{{CHANNEL} dihadrons}}") # Add a section for the channel
        
        # Loop over all versions
        for version in versions:
            VERSION=version.replace("_"," ")
            f.write(f"\\subsection{{{VERSION}}}") # Add a subsection for the version
            
            # Loop over all binstructs
            for binstruct in binstructs:
                dimension_names = binstruct["dimensionNames"]
                BINNING = '_'.join(dimension_names)
                # Define the plot filename and caption
                plotname = f'{project_dir}/systematics/bin_migration/{channel}/figure_{BINNING}_{version}_{cut}.png'
                caption = f"NEWLINE{CHANNEL}NEWLINEBinning scheme={BINNING}NEWLINEMonte Carlo Version={version}"
                #plotname = plotname.replace("_","\_")
                caption = caption.replace("_","\_").replace("NEWLINE","\\\\")
                # Write the LaTeX code for the plot and caption
                f.write("\\begin{figure}[ht]\n")
                f.write(f"\\includegraphics[width=\\textwidth]{{{plotname}}}\n")
                f.write(f"\\captionsetup{{font=large}}\n") # Set the caption font size to large
                f.write(f"\\caption{{{caption}}}\n")
                f.write("\\end{figure}\n")
            f.write("\\clearpage")
    # Write the LaTeX document postamble
    f.write("\\end{document}\n")
    
# Get the directory part of the LaTeX filename
latex_dirname = os.path.dirname(latex_filename)

# Save the current working directory
cwd = os.getcwd()

# Change the current working directory to the LaTeX directory
os.chdir(latex_dirname)

# Compile the LaTeX file into a PDF
os.system(f"pdflatex {latex_filename}")
os.system(f"pdflatex {latex_filename}")

# Change the current working directory back to the original
os.chdir(cwd)
# Out:
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
#
# (/work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bi
# n_migration/plots.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def)))
# (/usr/share/texlive/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/share/texlive/texmf-dist/tex/latex/fancyhdr/fancyhdr.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/caption/caption.sty
# (/usr/share/texlive/texmf-dist/tex/latex/caption/caption3.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# No file plots.aux.
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# ) (/usr/share/texlive/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
# (/usr/share/texlive/texmf-dist/tex/latex/latexconfig/epstopdf-sys.cfg))
# *geometry* driver: auto-detecting
# *geometry* detected driver: pdftex
# No file plots.toc.
# [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map} </work/clas12/users/gmat/
# clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piminu
# s/figure_x_MC_RGA_inbending_v3.png>] [2 </work/clas12/users/gmat/clas12/clas12_
# dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piminus/figure_z_MC_
# RGA_inbending_v3.png>] [3 </work/clas12/users/gmat/clas12/clas12_dihadrons/proj
# ects/ana_v1/systematics/bin_migration/piplus_piminus/figure_Mh_MC_RGA_inbending
# _v3.png>] [4 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/s
# ystematics/bin_migration/piplus_piminus/figure_x_Mh_MC_RGA_inbending_v3.png>]
# [5 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics
# /bin_migration/piplus_piminus/figure_z_Mh_MC_RGA_inbending_v3.png>] [6 </work/c
# las12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migrat
# ion/piplus_piminus/figure_x_MC_RGA_outbending_v3.png>] [7 </work/clas12/users/g
# mat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_pi
# minus/figure_z_MC_RGA_outbending_v3.png>] [8 </work/clas12/users/gmat/clas12/cl
# as12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piminus/figure_
# Mh_MC_RGA_outbending_v3.png>] [9 </work/clas12/users/gmat/clas12/clas12_dihadro
# ns/projects/ana_v1/systematics/bin_migration/piplus_piminus/figure_x_Mh_MC_RGA_
# outbending_v3.png>] [10 </work/clas12/users/gmat/clas12/clas12_dihadrons/projec
# ts/ana_v1/systematics/bin_migration/piplus_piminus/figure_z_Mh_MC_RGA_outbendin
# g_v3.png>] [11 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1
# /systematics/bin_migration/piplus_pi0/figure_x_MC_RGA_inbending_v4.png>]
# [12 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematic
# s/bin_migration/piplus_pi0/figure_z_MC_RGA_inbending_v4.png>] [13 </work/clas12
# /users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/p
# iplus_pi0/figure_Mh_MC_RGA_inbending_v4.png>] [14 </work/clas12/users/gmat/clas
# 12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_pi0/figure
# _x_Mh_MC_RGA_inbending_v4.png>] [15 </work/clas12/users/gmat/clas12/clas12_diha
# drons/projects/ana_v1/systematics/bin_migration/piplus_pi0/figure_z_Mh_MC_RGA_i
# nbending_v4.png>] [16 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects
# /ana_v1/systematics/bin_migration/piplus_pi0/figure_x_MC_RGA_outbending_v4.png>
# ] [17 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systemat
# ics/bin_migration/piplus_pi0/figure_z_MC_RGA_outbending_v4.png>] [18 </work/cla
# s12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migratio
# n/piplus_pi0/figure_Mh_MC_RGA_outbending_v4.png>] [19 </work/clas12/users/gmat/
# clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_pi0/fi
# gure_x_Mh_MC_RGA_outbending_v4.png>] [20 </work/clas12/users/gmat/clas12/clas12
# _dihadrons/projects/ana_v1/systematics/bin_migration/piplus_pi0/figure_z_Mh_MC_
# RGA_outbending_v4.png>] [21 </work/clas12/users/gmat/clas12/clas12_dihadrons/pr
# ojects/ana_v1/systematics/bin_migration/piplus_piplus/figure_x_MC_RGA_inbending
# _v6.png>] [22 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/
# systematics/bin_migration/piplus_piplus/figure_z_MC_RGA_inbending_v6.png>]
# [23 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematic
# s/bin_migration/piplus_piplus/figure_Mh_MC_RGA_inbending_v6.png>] [24 </work/cl
# as12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migrati
# on/piplus_piplus/figure_x_Mh_MC_RGA_inbending_v6.png>] [25 </work/clas12/users/
# gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_p
# iplus/figure_z_Mh_MC_RGA_inbending_v6.png>] [26 </work/clas12/users/gmat/clas12
# /clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piplus/figur
# e_x_MC_RGA_outbending_v6.png>] [27 </work/clas12/users/gmat/clas12/clas12_dihad
# rons/projects/ana_v1/systematics/bin_migration/piplus_piplus/figure_z_MC_RGA_ou
# tbending_v6.png>] [28 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects
# /ana_v1/systematics/bin_migration/piplus_piplus/figure_Mh_MC_RGA_outbending_v6.
# png>] [29 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/syst
# ematics/bin_migration/piplus_piplus/figure_x_Mh_MC_RGA_outbending_v6.png>]
# [30 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematic
# s/bin_migration/piplus_piplus/figure_z_Mh_MC_RGA_outbending_v6.png>] [31 </work
# /clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migr
# ation/pi0_pi0/figure_x_MC_RGA_inbending_v1.png>] [32 </work/clas12/users/gmat/c
# las12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/pi0_pi0/figure
# _z_MC_RGA_inbending_v1.png>] [33 </work/clas12/users/gmat/clas12/clas12_dihadro
# ns/projects/ana_v1/systematics/bin_migration/pi0_pi0/figure_Mh_MC_RGA_inbending
# _v1.png>] [34 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/
# systematics/bin_migration/pi0_pi0/figure_x_Mh_MC_RGA_inbending_v1.png>]
# [35 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematic
# s/bin_migration/pi0_pi0/figure_z_Mh_MC_RGA_inbending_v1.png>] [36 </work/clas12
# /users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/p
# i0_pi0/figure_x_MC_RGA_outbending_v1.png>] [37 </work/clas12/users/gmat/clas12/
# clas12_dihadrons/projects/ana_v1/systematics/bin_migration/pi0_pi0/figure_z_MC_
# RGA_outbending_v1.png>] [38 </work/clas12/users/gmat/clas12/clas12_dihadrons/pr
# ojects/ana_v1/systematics/bin_migration/pi0_pi0/figure_Mh_MC_RGA_outbending_v1.
# png>] [39 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/syst
# ematics/bin_migration/pi0_pi0/figure_x_Mh_MC_RGA_outbending_v1.png>] [40 </work
# /clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migr
# ation/pi0_pi0/figure_z_Mh_MC_RGA_outbending_v1.png>] [41 </work/clas12/users/gm
# at/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_pi
# 0/figure_x_MC_RGA_inbending_v4.png>] [42 </work/clas12/users/gmat/clas12/clas12
# _dihadrons/projects/ana_v1/systematics/bin_migration/piminus_pi0/figure_z_MC_RG
# A_inbending_v4.png>] [43 </work/clas12/users/gmat/clas12/clas12_dihadrons/proje
# cts/ana_v1/systematics/bin_migration/piminus_pi0/figure_Mh_MC_RGA_inbending_v4.
# png>] [44 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/syst
# ematics/bin_migration/piminus_pi0/figure_x_Mh_MC_RGA_inbending_v4.png>]
# [45 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematic
# s/bin_migration/piminus_pi0/figure_z_Mh_MC_RGA_inbending_v4.png>] [46 </work/cl
# as12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migrati
# on/piminus_pi0/figure_x_MC_RGA_outbending_v4.png>] [47 </work/clas12/users/gmat
# /clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_pi0/
# figure_z_MC_RGA_outbending_v4.png>] [48 </work/clas12/users/gmat/clas12/clas12_
# dihadrons/projects/ana_v1/systematics/bin_migration/piminus_pi0/figure_Mh_MC_RG
# A_outbending_v4.png>] [49 </work/clas12/users/gmat/clas12/clas12_dihadrons/proj
# ects/ana_v1/systematics/bin_migration/piminus_pi0/figure_x_Mh_MC_RGA_outbending
# _v4.png>] [50 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/
# systematics/bin_migration/piminus_pi0/figure_z_Mh_MC_RGA_outbending_v4.png>]
# [51 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematic
# s/bin_migration/piminus_piminus/figure_x_MC_RGA_inbending_v6.png>] [52 </work/c
# las12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migrat
# ion/piminus_piminus/figure_z_MC_RGA_inbending_v6.png>] [53 </work/clas12/users/
# gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_
# piminus/figure_Mh_MC_RGA_inbending_v6.png>] [54 </work/clas12/users/gmat/clas12
# /clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_piminus/fig
# ure_x_Mh_MC_RGA_inbending_v6.png>] [55 </work/clas12/users/gmat/clas12/clas12_d
# ihadrons/projects/ana_v1/systematics/bin_migration/piminus_piminus/figure_z_Mh_
# MC_RGA_inbending_v6.png>] [56 </work/clas12/users/gmat/clas12/clas12_dihadrons/
# projects/ana_v1/systematics/bin_migration/piminus_piminus/figure_x_MC_RGA_outbe
# nding_v6.png>] [57 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/an
# a_v1/systematics/bin_migration/piminus_piminus/figure_z_MC_RGA_outbending_v6.pn
# g>] [58 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/system
# atics/bin_migration/piminus_piminus/figure_Mh_MC_RGA_outbending_v6.png>]
# [59 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematic
# s/bin_migration/piminus_piminus/figure_x_Mh_MC_RGA_outbending_v6.png>] [60 </wo
# rk/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_mi
# gration/piminus_piminus/figure_z_Mh_MC_RGA_outbending_v6.png>] (./plots.aux) )<
# /usr/share/texlive/texmf-dist/fonts/type1/public/amsfonts/cm/cmbx12.pfb></usr/s
# hare/texlive/texmf-dist/fonts/type1/public/amsfonts/cm/cmmi10.pfb></usr/share/t
# exlive/texmf-dist/fonts/type1/public/amsfonts/cm/cmmi12.pfb></usr/share/texlive
# /texmf-dist/fonts/type1/public/amsfonts/cm/cmr10.pfb></usr/share/texlive/texmf-
# dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/share/texlive/texmf-dist/fo
# nts/type1/public/amsfonts/cm/cmr7.pfb></usr/share/texlive/texmf-dist/fonts/type
# 1/public/amsfonts/cm/cmr8.pfb></usr/share/texlive/texmf-dist/fonts/type1/public
# /amsfonts/cm/cmsy10.pfb></usr/share/texlive/texmf-dist/fonts/type1/public/amsfo
# nts/cm/cmsy7.pfb></usr/share/texlive/texmf-dist/fonts/type1/public/amsfonts/cm/
# cmsy8.pfb>
# Output written on plots.pdf (60 pages, 6100944 bytes).
# Transcript written on plots.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
#
# (/work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bi
# n_migration/plots.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def)))
# (/usr/share/texlive/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/share/texlive/texmf-dist/tex/latex/fancyhdr/fancyhdr.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/caption/caption.sty
# (/usr/share/texlive/texmf-dist/tex/latex/caption/caption3.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
# (./plots.aux)
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# ) (/usr/share/texlive/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
# (/usr/share/texlive/texmf-dist/tex/latex/latexconfig/epstopdf-sys.cfg))
# *geometry* driver: auto-detecting
# *geometry* detected driver: pdftex
# (./plots.toc) [1{/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}] [2 </work/
# clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migra
# tion/piplus_piminus/figure_x_MC_RGA_inbending_v3.png>] [3 </work/clas12/users/g
# mat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_pi
# minus/figure_z_MC_RGA_inbending_v3.png>] [4 </work/clas12/users/gmat/clas12/cla
# s12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piminus/figure_M
# h_MC_RGA_inbending_v3.png>] [5 </work/clas12/users/gmat/clas12/clas12_dihadrons
# /projects/ana_v1/systematics/bin_migration/piplus_piminus/figure_x_Mh_MC_RGA_in
# bending_v3.png>] [6 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/a
# na_v1/systematics/bin_migration/piplus_piminus/figure_z_Mh_MC_RGA_inbending_v3.
# png>] [7 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/syste
# matics/bin_migration/piplus_piminus/figure_x_MC_RGA_outbending_v3.png>]
# [8 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics
# /bin_migration/piplus_piminus/figure_z_MC_RGA_outbending_v3.png>] [9 </work/cla
# s12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migratio
# n/piplus_piminus/figure_Mh_MC_RGA_outbending_v3.png>] [10 </work/clas12/users/g
# mat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_pi
# minus/figure_x_Mh_MC_RGA_outbending_v3.png>] [11 </work/clas12/users/gmat/clas1
# 2/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piminus/fig
# ure_z_Mh_MC_RGA_outbending_v3.png>] [12 </work/clas12/users/gmat/clas12/clas12_
# dihadrons/projects/ana_v1/systematics/bin_migration/piplus_pi0/figure_x_MC_RGA_
# inbending_v4.png>] [13 </work/clas12/users/gmat/clas12/clas12_dihadrons/project
# s/ana_v1/systematics/bin_migration/piplus_pi0/figure_z_MC_RGA_inbending_v4.png>
# ] [14 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systemat
# ics/bin_migration/piplus_pi0/figure_Mh_MC_RGA_inbending_v4.png>] [15 </work/cla
# s12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migratio
# n/piplus_pi0/figure_x_Mh_MC_RGA_inbending_v4.png>] [16 </work/clas12/users/gmat
# /clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_pi0/f
# igure_z_Mh_MC_RGA_inbending_v4.png>] [17 </work/clas12/users/gmat/clas12/clas12
# _dihadrons/projects/ana_v1/systematics/bin_migration/piplus_pi0/figure_x_MC_RGA
# _outbending_v4.png>] [18 </work/clas12/users/gmat/clas12/clas12_dihadrons/proje
# cts/ana_v1/systematics/bin_migration/piplus_pi0/figure_z_MC_RGA_outbending_v4.p
# ng>] [19 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/syste
# matics/bin_migration/piplus_pi0/figure_Mh_MC_RGA_outbending_v4.png>] [20 </work
# /clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migr
# ation/piplus_pi0/figure_x_Mh_MC_RGA_outbending_v4.png>] [21 </work/clas12/users
# /gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_
# pi0/figure_z_Mh_MC_RGA_outbending_v4.png>] [22 </work/clas12/users/gmat/clas12/
# clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piplus/figure
# _x_MC_RGA_inbending_v6.png>] [23 </work/clas12/users/gmat/clas12/clas12_dihadro
# ns/projects/ana_v1/systematics/bin_migration/piplus_piplus/figure_z_MC_RGA_inbe
# nding_v6.png>] [24 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/an
# a_v1/systematics/bin_migration/piplus_piplus/figure_Mh_MC_RGA_inbending_v6.png>
# ] [25 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systemat
# ics/bin_migration/piplus_piplus/figure_x_Mh_MC_RGA_inbending_v6.png>] [26 </wor
# k/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_mig
# ration/piplus_piplus/figure_z_Mh_MC_RGA_inbending_v6.png>] [27 </work/clas12/us
# ers/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/pipl
# us_piplus/figure_x_MC_RGA_outbending_v6.png>] [28 </work/clas12/users/gmat/clas
# 12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piplus_piplus/fig
# ure_z_MC_RGA_outbending_v6.png>] [29 </work/clas12/users/gmat/clas12/clas12_dih
# adrons/projects/ana_v1/systematics/bin_migration/piplus_piplus/figure_Mh_MC_RGA
# _outbending_v6.png>] [30 </work/clas12/users/gmat/clas12/clas12_dihadrons/proje
# cts/ana_v1/systematics/bin_migration/piplus_piplus/figure_x_Mh_MC_RGA_outbendin
# g_v6.png>] [31 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1
# /systematics/bin_migration/piplus_piplus/figure_z_Mh_MC_RGA_outbending_v6.png>]
# [32 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematic
# s/bin_migration/pi0_pi0/figure_x_MC_RGA_inbending_v1.png>] [33 </work/clas12/us
# ers/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/pi0_
# pi0/figure_z_MC_RGA_inbending_v1.png>] [34 </work/clas12/users/gmat/clas12/clas
# 12_dihadrons/projects/ana_v1/systematics/bin_migration/pi0_pi0/figure_Mh_MC_RGA
# _inbending_v1.png>] [35 </work/clas12/users/gmat/clas12/clas12_dihadrons/projec
# ts/ana_v1/systematics/bin_migration/pi0_pi0/figure_x_Mh_MC_RGA_inbending_v1.png
# >] [36 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systema
# tics/bin_migration/pi0_pi0/figure_z_Mh_MC_RGA_inbending_v1.png>] [37 </work/cla
# s12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migratio
# n/pi0_pi0/figure_x_MC_RGA_outbending_v1.png>] [38 </work/clas12/users/gmat/clas
# 12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/pi0_pi0/figure_z_
# MC_RGA_outbending_v1.png>] [39 </work/clas12/users/gmat/clas12/clas12_dihadrons
# /projects/ana_v1/systematics/bin_migration/pi0_pi0/figure_Mh_MC_RGA_outbending_
# v1.png>] [40 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/s
# ystematics/bin_migration/pi0_pi0/figure_x_Mh_MC_RGA_outbending_v1.png>]
# [41 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematic
# s/bin_migration/pi0_pi0/figure_z_Mh_MC_RGA_outbending_v1.png>] [42 </work/clas1
# 2/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/
# piminus_pi0/figure_x_MC_RGA_inbending_v4.png>] [43 </work/clas12/users/gmat/cla
# s12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_pi0/figu
# re_z_MC_RGA_inbending_v4.png>] [44 </work/clas12/users/gmat/clas12/clas12_dihad
# rons/projects/ana_v1/systematics/bin_migration/piminus_pi0/figure_Mh_MC_RGA_inb
# ending_v4.png>] [45 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/a
# na_v1/systematics/bin_migration/piminus_pi0/figure_x_Mh_MC_RGA_inbending_v4.png
# >] [46 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systema
# tics/bin_migration/piminus_pi0/figure_z_Mh_MC_RGA_inbending_v4.png>] [47 </work
# /clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migr
# ation/piminus_pi0/figure_x_MC_RGA_outbending_v4.png>] [48 </work/clas12/users/g
# mat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_p
# i0/figure_z_MC_RGA_outbending_v4.png>] [49 </work/clas12/users/gmat/clas12/clas
# 12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_pi0/figure_Mh_MC
# _RGA_outbending_v4.png>] [50 </work/clas12/users/gmat/clas12/clas12_dihadrons/p
# rojects/ana_v1/systematics/bin_migration/piminus_pi0/figure_x_Mh_MC_RGA_outbend
# ing_v4.png>] [51 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_
# v1/systematics/bin_migration/piminus_pi0/figure_z_Mh_MC_RGA_outbending_v4.png>]
# [52 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematic
# s/bin_migration/piminus_piminus/figure_x_MC_RGA_inbending_v6.png>] [53 </work/c
# las12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migrat
# ion/piminus_piminus/figure_z_MC_RGA_inbending_v6.png>] [54 </work/clas12/users/
# gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_
# piminus/figure_Mh_MC_RGA_inbending_v6.png>] [55 </work/clas12/users/gmat/clas12
# /clas12_dihadrons/projects/ana_v1/systematics/bin_migration/piminus_piminus/fig
# ure_x_Mh_MC_RGA_inbending_v6.png>] [56 </work/clas12/users/gmat/clas12/clas12_d
# ihadrons/projects/ana_v1/systematics/bin_migration/piminus_piminus/figure_z_Mh_
# MC_RGA_inbending_v6.png>] [57 </work/clas12/users/gmat/clas12/clas12_dihadrons/
# projects/ana_v1/systematics/bin_migration/piminus_piminus/figure_x_MC_RGA_outbe
# nding_v6.png>] [58 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/an
# a_v1/systematics/bin_migration/piminus_piminus/figure_z_MC_RGA_outbending_v6.pn
# g>] [59 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/system
# atics/bin_migration/piminus_piminus/figure_Mh_MC_RGA_outbending_v6.png>]
# [60 </work/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematic
# s/bin_migration/piminus_piminus/figure_x_Mh_MC_RGA_outbending_v6.png>] [61 </wo
# rk/clas12/users/gmat/clas12/clas12_dihadrons/projects/ana_v1/systematics/bin_mi
# gration/piminus_piminus/figure_z_Mh_MC_RGA_outbending_v6.png>] (./plots.aux) )<
# /usr/share/texlive/texmf-dist/fonts/type1/public/amsfonts/cm/cmbx10.pfb></usr/s
# hare/texlive/texmf-dist/fonts/type1/public/amsfonts/cm/cmbx12.pfb></usr/share/t
# exlive/texmf-dist/fonts/type1/public/amsfonts/cm/cmmi10.pfb></usr/share/texlive
# /texmf-dist/fonts/type1/public/amsfonts/cm/cmmi12.pfb></usr/share/texlive/texmf
# -dist/fonts/type1/public/amsfonts/cm/cmr10.pfb></usr/share/texlive/texmf-dist/f
# onts/type1/public/amsfonts/cm/cmr12.pfb></usr/share/texlive/texmf-dist/fonts/ty
# pe1/public/amsfonts/cm/cmr7.pfb></usr/share/texlive/texmf-dist/fonts/type1/publ
# ic/amsfonts/cm/cmr8.pfb></usr/share/texlive/texmf-dist/fonts/type1/public/amsfo
# nts/cm/cmsy10.pfb></usr/share/texlive/texmf-dist/fonts/type1/public/amsfonts/cm
# /cmsy7.pfb></usr/share/texlive/texmf-dist/fonts/type1/public/amsfonts/cm/cmsy8.
# pfb>
# Output written on plots.pdf (61 pages, 6113283 bytes).
# Transcript written on plots.log.
